# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("Employee_Burnout_8000.csv")
df
# Out:
#       employee_id  age  gender  department  job_level  workload  \
# 0               1   59    Male     Support          5        48
# 1               2   49    Male          IT          3        60
# 2               3   35    Male  Operations          5        67
# 3               4   28    Male     Support          3        51
# 4               5   41  Female          IT          4        43
# ...           ...  ...     ...         ...        ...       ...
# 7995         7996   40  Female   Marketing          5        23
# 7996         7997   49  Female          HR          3        42
# 7997         7998   48  Female   Marketing          4        42
# 7998         7999   28  Female          HR          1        68
# 7999         8000   44  Female     Finance          2        53
#
#       overtime_hours  job_satisfaction  stress_level  sleep_quality  \
# 0                 20                 4             8              1
# ...

# %%
df.head()
# Out:
#    employee_id  age  gender  department  job_level  workload  overtime_hours  \
# 0            1   59    Male     Support          5        48              20
# 1            2   49    Male          IT          3        60              21
# 2            3   35    Male  Operations          5        67               0
# 3            4   28    Male     Support          3        51              29
# 4            5   41  Female          IT          4        43              27
#
#    job_satisfaction  stress_level  sleep_quality  work_life_balance  \
# 0                 4             8              1                  3
# 1                 4             2              9                  2
# 2                 4             1              7                  1
# 3                 5             2              3                  3
# 4                 5             2              2                  1
#
#    burnout_risk
# 0             1
# 1             1
# 2             0
# 3             1
# ...

# %%
df.tail()
# Out:
#       employee_id  age  gender department  job_level  workload  \
# 7995         7996   40  Female  Marketing          5        23
# 7996         7997   49  Female         HR          3        42
# 7997         7998   48  Female  Marketing          4        42
# 7998         7999   28  Female         HR          1        68
# 7999         8000   44  Female    Finance          2        53
#
#       overtime_hours  job_satisfaction  stress_level  sleep_quality  \
# 7995              25                 4             2              2
# 7996               1                 2             2              4
# 7997              13                 1             7              8
# 7998               6                 4             9              4
# 7999              16                 2             6              5
#
#       work_life_balance  burnout_risk
# 7995                  3             0
# 7996                  2             0
# 7997                  3             0
# ...

# %%
df.shape
# Out:
# (8000, 12)

# %%
df.columns
# Out:
# Index(['employee_id', 'age', 'gender', 'department', 'job_level', 'workload',
#        'overtime_hours', 'job_satisfaction', 'stress_level', 'sleep_quality',
#        'work_life_balance', 'burnout_risk'],
#       dtype='object')

# %%
df.dtypes
# Out:
# employee_id           int64
# age                   int64
# gender               object
# department           object
# job_level             int64
# workload              int64
# overtime_hours        int64
# job_satisfaction      int64
# stress_level          int64
# sleep_quality         int64
# work_life_balance     int64
# burnout_risk          int64
# dtype: object

# %%
df.isna().sum()
# Out:
# employee_id          0
# age                  0
# gender               0
# department           0
# job_level            0
# workload             0
# overtime_hours       0
# job_satisfaction     0
# stress_level         0
# sleep_quality        0
# work_life_balance    0
# burnout_risk         0
# dtype: int64

# %%
df.drop(['employee_id'], axis=1, inplace=True) 
df.head()
# Out:
#    age  gender  department  job_level  workload  overtime_hours  \
# 0   59    Male     Support          5        48              20
# 1   49    Male          IT          3        60              21
# 2   35    Male  Operations          5        67               0
# 3   28    Male     Support          3        51              29
# 4   41  Female          IT          4        43              27
#
#    job_satisfaction  stress_level  sleep_quality  work_life_balance  \
# 0                 4             8              1                  3
# 1                 4             2              9                  2
# 2                 4             1              7                  1
# 3                 5             2              3                  3
# 4                 5             2              2                  1
#
#    burnout_risk
# 0             1
# 1             1
# 2             0
# 3             1
# 4             1

# %%
df.columns
# Out:
# Index(['age', 'gender', 'department', 'job_level', 'workload',
#        'overtime_hours', 'job_satisfaction', 'stress_level', 'sleep_quality',
#        'work_life_balance', 'burnout_risk'],
#       dtype='object')

# %%
df.describe()
# Out:
#                age    job_level     workload  overtime_hours  \
# count  8000.000000  8000.000000  8000.000000     8000.000000
# mean     40.174875     3.020500    44.707000       14.653000
# std      11.191323     1.413623    14.295531        8.664928
# min      21.000000     1.000000    20.000000        0.000000
# 25%      31.000000     2.000000    32.000000        7.000000
# 50%      40.000000     3.000000    45.000000       15.000000
# 75%      50.000000     4.000000    57.000000       22.000000
# max      59.000000     5.000000    69.000000       29.000000
#
#        job_satisfaction  stress_level  sleep_quality  work_life_balance  \
# count       8000.000000   8000.000000    8000.000000        8000.000000
# mean           3.008125      5.029875       5.002375           2.506375
# std            1.402517      2.578917       2.580446           1.125330
# min            1.000000      1.000000       1.000000           1.000000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['department'].unique()
# Out:
# array(['Support', 'IT', 'Operations', 'HR', 'Marketing', 'Sales',
#        'Finance'], dtype=object)

# %%
# Count values of each age
df1 = df['age'].value_counts()

# Bar chart
plt.figure(figsize=(10,5))
plt.bar(df1.index, df1.values, color='teal')

# Add title and labels
plt.title('Number of Employees by Age', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)


plt.show()

# %%
df2 = df['job_level'].value_counts()


plt.figure(figsize=(10,5))
plt.bar(df1.index, df1.values, color='r')

# Add title and labels
plt.title('Number of Employees by job level', fontsize=16)
plt.xlabel('Job level', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)


plt.show()

# %%
# Count values for workload
df3 = df['workload'].value_counts().sort_index()

# Bar chart
plt.figure(figsize=(10,5))
plt.bar(df3.index, df3.values, color='green')

# Add title and labels
plt.title('Distribution of Workload', fontsize=16)
plt.xlabel('Workload', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)

plt.show()

# %%
gender_counts = df['gender'].value_counts()

# Pie chart
plt.figure(figsize=(7,7))
plt.pie(gender_counts.values, 
        labels=gender_counts.index, 
        autopct='%.2f%%', 
        colors=sns.color_palette('Set2', len(gender_counts)),
        startangle=140)
plt.title('Gender Distribution of Employees', fontsize=16)
plt.show()

# %%
df5 = df['sleep_quality'].value_counts().sort_index()

plt.figure(figsize=(8,5))
plt.bar(df5.index, df5.values, color='purple')
plt.title('Distribution of Sleep Quality', fontsize=16)
plt.xlabel('Sleep Quality Score', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)

plt.show()

# %%
df6 = df['overtime_hours'].value_counts().sort_index()

plt.figure(figsize=(10,5))
plt.bar(df6.index, df6.values, color='orange')
plt.title('Distribution of Overtime Hours', fontsize=16)
plt.xlabel('Overtime Hours', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)
plt.show()

# %%
df7 = df['job_satisfaction'].value_counts().sort_index()

plt.figure(figsize=(7,7))
plt.pie(df7.values, 
        labels=df7.index, 
        autopct='%.2f%%')
    
plt.title('Job Satisfaction Distribution', fontsize=16)
plt.show()

# %%
df8 = df['stress_level'].value_counts().sort_index()

plt.figure(figsize=(10,5))
plt.bar(df8.index, df8.values, color='red')
plt.title('Distribution of Stress Level', fontsize=16)
plt.xlabel('Stress Level Score', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)
plt.show()

# %%
df9 = df['work_life_balance'].value_counts().sort_index()
plt.figure(figsize=(7,7))
plt.pie(df9.values, 
        labels=df9.index, 
        autopct='%.2f%%')
plt.title('Work-Life Balance Distribution', fontsize=16)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='stress_level', hue='burnout_risk', data=df)

# Add title and labels
plt.title('Stress Level vs Burnout Risk', fontsize=16)
plt.xlabel('Stress Level', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)
plt.legend(title='Burnout Risk', labels=['No (0)', 'Yes (1)'])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
df['gender']=lab.fit_transform(df['gender'])
df['department']=lab.fit_transform(df['department'])

# %%
df.dtypes
# Out:
# age                  int64
# gender               int64
# department           int64
# job_level            int64
# workload             int64
# overtime_hours       int64
# job_satisfaction     int64
# stress_level         int64
# sleep_quality        int64
# work_life_balance    int64
# burnout_risk         int64
# dtype: object

# %%
df.corr()
# Out:
#                         age    gender  department  job_level  workload  \
# age                1.000000 -0.021388    0.007033   0.011002  0.000491
# gender            -0.021388  1.000000   -0.000082  -0.000549  0.016133
# department         0.007033 -0.000082    1.000000  -0.001988  0.025686
# job_level          0.011002 -0.000549   -0.001988   1.000000  0.011958
# workload           0.000491  0.016133    0.025686   0.011958  1.000000
# overtime_hours    -0.019841 -0.004018    0.001661  -0.018842  0.003445
# job_satisfaction   0.015879 -0.005979   -0.002799   0.002880  0.000530
# stress_level       0.009158 -0.013732    0.009524   0.004907  0.016752
# sleep_quality      0.002994 -0.004506   -0.002644  -0.000836  0.007414
# work_life_balance -0.009693 -0.031333   -0.013229   0.017836 -0.010080
# burnout_risk      -0.000261  0.008755    0.026647   0.000058  0.664281
#
#                    overtime_hours  job_satisfaction  stress_level  \
# ...

# %%
sns.heatmap(data=df.corr())
# Out:
# <Axes: >

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[59,  1,  6, ...,  8,  1,  3],
#        [49,  1,  2, ...,  2,  9,  2],
#        [35,  1,  4, ...,  1,  7,  1],
#        ...,
#        [48,  0,  3, ...,  7,  8,  3],
#        [28,  0,  1, ...,  9,  4,  2],
#        [44,  0,  0, ...,  6,  5,  4]], shape=(8000, 10))

# %%
y=df.iloc[:,-1].values
y
# Out:
# array([1, 1, 0, ..., 0, 1, 1], shape=(8000,))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)
x_train
# Out:
# array([[22,  1,  3, ...,  2,  3,  3],
#        [49,  1,  6, ...,  1,  7,  1],
#        [56,  0,  0, ...,  2,  5,  2],
#        ...,
#        [53,  0,  3, ...,  4,  5,  4],
#        [23,  0,  1, ...,  9,  2,  1],
#        [22,  1,  4, ...,  8,  1,  1]], shape=(5600, 10))

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)
x_train
# Out:
# array([[-1.61838419,  0.99501244, -0.00558104, ..., -1.16989538,
#         -0.79484247,  0.44148298],
#        [ 0.78593602,  0.99501244,  1.48269542, ..., -1.55828844,
#          0.76626856, -1.33523617],
#        [ 1.4092783 , -1.00501256, -1.49385749, ..., -1.16989538,
#         -0.01428695, -0.4468766 ],
#        ...,
#        [ 1.14213161, -1.00501256, -0.00558104, ..., -0.39310926,
#         -0.01428695,  1.32984256],
#        [-1.5293353 , -1.00501256, -0.99776534, ...,  1.54885604,
#         -1.18512023, -1.33523617],
#        [-1.61838419,  0.99501244,  0.49051112, ...,  1.16046298,
#         -1.57539799, -1.33523617]], shape=(5600, 10))

# %%
#Model Creation
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=11)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([1, 0, 0, ..., 0, 1, 0], shape=(2400,))

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[1073,  122],
#        [ 112, 1093]])

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.9025

# %%
#DECISION TREE

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
dt_model = DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
y_pred_dt=dt_model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9025

# %%
#Hyper parameter Tunning
from sklearn.model_selection import GridSearchCV
model=KNeighborsClassifier()                                            #parameter       crossvaluveion(cv)
data={'n_neighbors':[3,5,7,9,11],'weights':['uniform','distance']}
clf=GridSearchCV(model,data,cv=10,scoring='accuracy')      #tunning
clf.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
import pickle

# Save trained KNN model
with open("knn_model.pkl", "wb") as f:
    pickle.dump(model, f)

# Save the scaler
with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)
